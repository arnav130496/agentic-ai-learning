# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import importlib
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().resolve().parent))

import src.graph.nodes as graph_nodes
import src.graph.build_graph as build_graph_module
import src.graph as graph_package

graph_nodes = importlib.reload(graph_nodes)
build_graph_module = importlib.reload(build_graph_module)
graph_package = importlib.reload(graph_package)

from src.graph.build_graph import graph
from src.graph import TEST_QUERIES

for case in TEST_QUERIES:
    print("Query:", case["query"])
    final_state = graph.invoke(case)
    print("Confidence:", final_state["confidence_score"])
    print("Answer:", final_state["answer"])
    print("Citations:", final_state["citations"])
    print("-" * 40)
# Out:
# Query: How much PTO do employees accrue per month?
# Confidence: 0.6233333333333333
# Answer: Employees accrue 1.5 days of PTO per month.
# Citations: ['c1 : hr_policy_pto.md', 'c2 : hr_policy_pto.md', 'c6 : hr_policy_onboarding.md']
# ----------------------------------------
# Query: What is the company's policy on parental leave?
# Confidence: 0.26
# Answer: Evidence is insufficient to answer the query.
# Citations: []
# ----------------------------------------
# Query: How long do I have to submit an expense report?
# Confidence: 0.3833333333333333
# Answer: Evidence is insufficient to answer the query.
# Citations: []
# ----------------------------------------
